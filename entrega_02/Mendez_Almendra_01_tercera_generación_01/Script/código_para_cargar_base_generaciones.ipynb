# %%
import pandas as pd
datos = pd.read_csv("/content/Tercera_Generación_(Base Alme)_limpia.csv", delimiter= ";")
datos
# Out:
#        GRUPO                 EMPRESA  AÑO DEBUT    AÑO FIN   GÉNERO  \
# 0        BOB4        In Entertainment      2012       2012  Hombres
# 1         D.Q             JL Entercom      2012       2012  Mujeres
# 2     Goddess        KW Entertainment      2012       2012  Mujeres
# 3        LXIA           2J Production      2012       2012  Mujeres
# 4        Ne.P     Naeum Entertainment      2012       2012  Mujeres
# ..        ...                     ...       ...        ...      ...
# 490  Triple T    S.M. Ent. y JYP Ent.      2016       2016    Mixto
# 491    DIP MX  Inter BD Entertainment      2016   presente    Mixto
# 492      Kard               DSP Media      2016   presente    Mixto
# 493  Triple H      Cube Entertainment      2017       2018    Mixto
# 494       NaN                     NaN       NaN        NaN      NaN
#
#     N° MIEMBROS  Chile (SI/NO) OYENTES SPOTIFY  Unnamed: 8
# 0             4            0.0       Sin datos         NaN
# ...
