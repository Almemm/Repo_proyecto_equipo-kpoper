# %%
import pandas as pd
datos = pd.read_csv ("/content/drive/MyDrive/conciertos_database_limpia.csv", encoding = "latin1", delimiter = ";")
datos
# Out:
#           GRUPO TIPO DE EVENTO  AÑO      MES           PAÍS     CIUDAD   \
# 0    Stray Kids       Showcase  2019    Enero     Tailandia     Bangkok
# 1    Stray Kids       Showcase  2019    Enero     Indonesia     Yakarta
# 2    Stray Kids       Showcase  2019  Febrero     Australia   Melbourne
# 3    Stray Kids       Showcase  2019  Febrero     Australia      Sídney
# 4    Stray Kids       Showcase  2019    Abril     Filipinas      Manila
# ..          ...            ...   ...      ...           ...         ...
# 313       ARTMS      Concierto  2025     Mayo  Países Bajos   Eindhoven
# 314       ARTMS      Concierto  2025     Mayo       Francia       París
# 315       ARTMS      Concierto  2025     Mayo        Italia       Milán
# 316       ARTMS      Concierto  2025     Mayo     Dinamarca  Copenhague
# 317       ARTMS      Concierto  2025     Mayo      Polonia     Varsovia
#
#                              RECINTO  CAPACIDAD             NOMBRE GIRA
# ...
