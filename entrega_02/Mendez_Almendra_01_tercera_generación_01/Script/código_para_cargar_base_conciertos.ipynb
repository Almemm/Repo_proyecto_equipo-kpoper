# %%
import pandas as pd
datos = pd.read_csv("/content/Conciertos_Tercera_Generación_limpia.csv", delimiter= ";")
datos
# Out:
#          GRUPO                                        NOMBRE TOUR  AÑO   MES   \
# 0          BTS  BTS 1st World Tour "BTS Live Trilogy: Episode ...  2014    10
# 1          BTS  BTS 1st World Tour "BTS Live Trilogy: Episode ...  2014    11
# 2          BTS  BTS 1st World Tour "BTS Live Trilogy: Episode ...  2014    11
# 3          BTS  BTS 1st World Tour "BTS Live Trilogy: Episode ...  2014    12
# 4          BTS  BTS 1st World Tour "BTS Live Trilogy: Episode ...  2014    12
# ..         ...                                                ...   ...   ...
# 280  SEVENTEEN                  SEVENTEEN "RIGHT HERE" WORLD TOUR  2024    12
# 281  SEVENTEEN                  SEVENTEEN "RIGHT HERE" WORLD TOUR  2024    12
# 282  SEVENTEEN                  SEVENTEEN "RIGHT HERE" WORLD TOUR  2025     1
# 283  SEVENTEEN                  SEVENTEEN "RIGHT HERE" WORLD TOUR  2025     2
# 284  SEVENTEEN                  SEVENTEEN "RIGHT HERE" WORLD TOUR  2025     2
#
# ...
